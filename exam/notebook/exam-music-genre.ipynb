# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
songs_data = pd.read_csv("../data/general_data/songs_data.csv")

# %%
songs_data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity playlist_name             playlist_id  \
# 0        Ed Sheeran                66     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 1          Maroon 5                67     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 2      Zara Larsson                70     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 3  The Chainsmokers                60     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 4     Lewis Capaldi                69     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
#
# ...

# %% [markdown]
# # 1.0 Basic Information of the data

# %%
list(songs_data.columns)
# Out:
# ['track_id',
#  'track_name',
#  'track_artist',
#  'track_popularity',
#  'playlist_name',
#  'playlist_id',
#  'genre',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %%
songs_data.shape
# Out:
# (32833, 19)

# %%
type(songs_data)
# Out:
# pandas.core.frame.DataFrame

# %%
songs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          32833 non-null  object
#  1   track_name        32828 non-null  object
#  2   track_artist      32828 non-null  object
#  3   track_popularity  32833 non-null  int64
#  4   playlist_name     32833 non-null  object
#  5   playlist_id       32833 non-null  object
#  6   genre             32833 non-null  object
#  7   danceability      32833 non-null  float64
#  8   energy            32833 non-null  float64
#  9   key               32833 non-null  int64
#  10  loudness          32833 non-null  float64
#  11  mode              32833 non-null  int64
#  12  speechiness       32833 non-null  float64
#  13  acousticness      32833 non-null  float64
#  14  instrumentalness  32833 non-null  float64
#  15  liveness          32833 non-null  float64
# ...

# %%
# Identify duplicates based on specific columns (e.g., 'mode' and 'genre')
duplicates = songs_data.duplicated(subset=["track_name", "track_artist","playlist_name"])
print(f"Number of duplicate rows: {duplicates.sum()}")
print("Duplicate rows:\n", songs_data[duplicates])
duplicates.head()
# Out:
# Number of duplicate rows: 658
# Duplicate rows:
#                       track_id  \
# 510    2V65y3PX4DkRhy1djlxd9p
# 527    2AVredtzre1KADDXWoGd4I
# 1348   4VginDwYTP2eaHJzO0QMjG
# 1349   421leiR6jKlH5KDdwLYrOs
# 1358   4evmHXcjt3bTUHD1cvny97
# ...                       ...
# 31121  5fp6j7TdmXpmKM6QEDL6ZA
# 31122  1CuBioSnK1CMLeKDmNpoix
# 31482  4gjrsP1Tmrqh1IiHhMXQm5
# 31536  1dssHOp3HpaK9o5c0CL7xU
# 31863  7LzahanKFAWdfrqKEjiUli
#
#                                               track_name         track_artist  \
# 510                   Don't You Worry Child - Radio Edit  Swedish House Mafia
# 527                                      Like I Love You     Lost Frequencies
# 1348                                             Circles          Post Malone
# 1349                                        Dance Monkey          Tones and I
# 1358                     Beautiful People (feat. Khalid)           Ed Sheeran
# ...

# %%
# distribution of dancebility
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.danceability, x=songs_data.genre, hue=songs_data.genre)
plt.title("dancebility of each gerne", size=10);

# %%
# distribution of energy 
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.energy, x=songs_data.genre, hue=songs_data.genre)
plt.title("energy of each gerne", size=10);

# %%
# distribution of key
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.key, x=songs_data.genre, hue=songs_data.genre)
plt.title("key of each gerne", size=10);

# %%
# distribution of loudness
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.loudness, x=songs_data.genre, hue=songs_data.genre)
plt.title("loudness of each gerne", size=10);

# %%
# distribution of mode
# Attempt to convert 'mode' to numeric, setting errors='coerce' will turn non-numeric values into NaN
songs_data['mode'] = pd.to_numeric(songs_data['mode'], errors='coerce')

# Drop rows with NaN in 'mode' column
songs_data = songs_data.dropna(subset=['mode'])

# Now plot the data
sns.boxplot(y=songs_data['mode'], x=songs_data['genre'], hue=songs_data['genre'])
plt.title("Mode of each Genre", size=10)
plt.show()
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.mode, x=songs_data.genre, hue=songs_data.genre)
plt.title("mode of each gerne", size=10);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File lib.pyx:2374, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 14
#      11 plt.show()
#      12 plt.rcParams["figure.figsize"] = (6,4)
# ---> 14 sns.boxplot(y=songs_data.mode, x=songs_data.genre, hue=songs_data.genre)
#      15 plt.title("mode of each gerne", size=10);
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
# ...

# %%
# distribution of speechiness
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.speechiness, x=songs_data.genre, hue=songs_data.genre)
plt.title("speechiness of each gerne", size=10);

# %%
# distribution of acousticness
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.acousticness, x=songs_data.genre, hue=songs_data.genre)
plt.title("acousticness of each gerne", size=10);

# %%
# distribution of instrumentalness
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.instrumentalness, x=songs_data.genre, hue=songs_data.genre)
plt.title("instrumentalness of each gerne", size=10);

# %%
# distribution of liveness
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.liveness, x=songs_data.genre, hue=songs_data.genre)
plt.title("liveness of each gerne", size=10);

# %%
# distribution of valence 
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.valence, x=songs_data.genre, hue=songs_data.genre)
plt.title("valence of each gerne", size=10);

# %%
# distribution of tempo
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.tempo, x=songs_data.genre, hue=songs_data.genre)
plt.title("tempo of each gerne", size=10);

# %%
# distribution of duration_ms
plt.rcParams["figure.figsize"] = (6,4)

sns.boxplot(y=songs_data.duration_ms, x=songs_data.genre, hue=songs_data.genre)
plt.title("duration_ms of each gerne", size=10);

# %%
#identify all the features that need encoding
list(songs_data.select_dtypes('object').columns)
# Out:
# ['track_id',
#  'track_name',
#  'track_artist',
#  'playlist_name',
#  'playlist_id',
#  'genre']

# %%
#identify all the features that need encoding
list(songs_data.select_dtypes('float64').columns)
# Out:
# ['danceability',
#  'energy',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo']

# %%
#identify all the features that need encoding
list(songs_data.select_dtypes('int64').columns)
# Out:
# ['track_popularity', 'key', 'mode', 'duration_ms']

# %%
list(songs_data.columns)
# Out:
# ['track_id',
#  'track_name',
#  'track_artist',
#  'track_popularity',
#  'playlist_name',
#  'playlist_id',
#  'genre',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %%
#the categories of track_id
songs_data.track_id.value_counts()
# Out:
# track_id
# 7BKLCZ1jbUBVqRi2FVlTVw    10
# 14sOS5L36385FJ3OL8hew4     9
# 3eekarcy7kvN4yt5ZFzltW     9
# 2Fxmhks0bxGSBdJ92vM42m     8
# 2tnVG71enUj33Ic2nFN6kZ     8
#                           ..
# 3AKwyujeGxTQSZNbx9Ka3c     1
# 3ITvHA9zhZZdBJsOsAUegF     1
# 5gsW8TMmNVnevjq13h0Nlp     1
# 4pN4icvWINm9uN3bElfbec     1
# 29zWqhca3zt5NsckZqDf6c     1
# Name: count, Length: 28356, dtype: int64

# %%
#the categories of track_name
songs_data.track_name.value_counts()
# Out:
# track_name
# Poison                    22
# Breathe                   21
# Alive                     20
# Forever                   20
# Stay                      19
#                           ..
# Quien Eres Tu              1
# Como Nadie                 1
# Ya No Estás Aquí           1
# Ojala                      1
# Typhoon - Original Mix     1
# Name: count, Length: 23449, dtype: int64

# %%
#the categories of track_artist
songs_data.track_artist.value_counts()
# Out:
# track_artist
# Martin Garrix       161
# Queen               136
# The Chainsmokers    123
# David Guetta        110
# Don Omar            102
#                    ...
# Underworld            1
# The Witches           1
# Tess Parks            1
# Mick Harvey           1
# Mat Zo                1
# Name: count, Length: 10692, dtype: int64

# %%
#the categories of track_popularity
songs_data.track_popularity.value_counts()
# Out:
# track_popularity
# 0      2703
# 1       575
# 57      541
# 60      514
# 51      514
#        ...
# 97       22
# 95       15
# 96        7
# 99        4
# 100       2
# Name: count, Length: 101, dtype: int64

# %%
#the categories of track_popularity
songs_data.track_popularity.value_counts()
# Out:
# track_popularity
# 0      2703
# 1       575
# 57      541
# 60      514
# 51      514
#        ...
# 97       22
# 95       15
# 96        7
# 99        4
# 100       2
# Name: count, Length: 101, dtype: int64

# %%
#the categories of playlist_name
songs_data.playlist_name.value_counts()
# Out:
# playlist_name
# Indie Poptimism                                              308
# 2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥               247
# Permanent Wave                                               244
# Hard Rock Workout                                            219
# Ultimate Indie Presents... Best Indie Tracks of the 2010s    198
#                                                             ...
# CSR 103:9 (GTA: SA)                                            7
# Big White Room-Jessie-J                                        7
# TOP 50 GLOBAL 2020 UPDATED WEEKLY 🌍🎶 WORLDWIDE                 6
# ALPAS Music Festival                                           3
# Post-Teen Pop                                                  1
# Name: count, Length: 449, dtype: int64

# %%
#the categories of playlist_id
songs_data.playlist_id.value_counts()
# Out:
# playlist_id
# 4JkkvMpVl4lSioqQjeAL0q    247
# 37i9dQZF1DWTHM4kX49UKs    198
# 6KnQDwp0syvhfHOR4lWP7x    195
# 3xMQTDLOIGvj3lWH5e5x6F    189
# 3Ho3iO0iJykgEQNbjB2sic    182
#                          ...
# 4sr2xEhXQR5VuZ0LZX8TQ8      7
# 6dqoVI7qwYLyNqbg0MPad3      7
# 2CJsD3fcYJWcliEKnwmovU      6
# 6pPpLz42hUkr8gbMirkAEl      3
# 6HprqD6WZMx5peClrxaprN      1
# Name: count, Length: 471, dtype: int64

# %% [markdown]
# # 2.0 Reindex the data

# %%
songs_data_reindex=songs_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'track_popularity',
                                       'danceability',
                                       'energy',
                                       'key',
                                       'loudness',
                                       'mode',
                                       'speechiness',
                                       'acousticness',
                                       'instrumentalness',
                                       'liveness',
                                       'valence',
                                       'tempo',
                                       'duration_ms'], 
                                        axis=1)

songs_data_reindex.head()
# Out:
#   genre playlist_name      track_artist  \
# 0   pop     Pop Remix        Ed Sheeran
# 1   pop     Pop Remix          Maroon 5
# 2   pop     Pop Remix      Zara Larsson
# 3   pop     Pop Remix  The Chainsmokers
# 4   pop     Pop Remix     Lewis Capaldi
#
#                                           track_name  track_popularity  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...                66
# 1                    Memories - Dillon Francis Remix                67
# 2                    All the Time - Don Diablo Remix                70
# 3                  Call You Mine - Keanu Silva Remix                60
# 4            Someone You Loved - Future Humans Remix                69
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# ...

# %%
# save the data

songs_data_reindex.to_csv("../data/general_data/songs_data_reindex.csv", index=False)

# %%
# distribution of height
plt.rcParams["figure.figsize"] = (2.5,4)

sns.boxplot(y=songs_data_reindex.dancibility, x=songs_data_reindex.genre, hue=tinder_data.sex)
plt.title("dancebility of each gerne", size=10);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 # distribution of height
#       2 plt.rcParams["figure.figsize"] = (2.5,4)
# ----> 4 sns.boxplot(y=songs_data_reindex.dancibility, x=songs_data_reindex.genre, hue=tinder_data.sex)
#       5 plt.title("dancebility of each gerne", size=10);
#
# NameError: name 'songs_data_reindex' is not defined

# %% [markdown]
# # 3.0 Data of different genre

# %% [markdown]
# ## 3.1 Data of pop

# %%
pop_data=songs_data_reindex[songs_data_reindex.genre == "pop"]

# %%
pop_data.head()
# Out:
#   genre playlist_name      track_artist  \
# 0   pop     Pop Remix        Ed Sheeran
# 1   pop     Pop Remix          Maroon 5
# 2   pop     Pop Remix      Zara Larsson
# 3   pop     Pop Remix  The Chainsmokers
# 4   pop     Pop Remix     Lewis Capaldi
#
#                                           track_name  track_popularity  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...                66
# 1                    Memories - Dillon Francis Remix                67
# 2                    All the Time - Don Diablo Remix                70
# 3                  Call You Mine - Keanu Silva Remix                60
# 4            Someone You Loved - Future Humans Remix                69
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# ...

# %%
# save the data

pop_data.to_csv("../data/pop/pop_data.csv", index=False)

# %%
pop_data.shape
# Out:
# (5507, 17)

# %%
pop_data.playlist_name.value_counts()
# Out:
# playlist_name
# Indie Poptimism                                    308
# post teen pop                                      166
# Dance Pop                                          138
# Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop    100
# Chillout & Remixes 💜                               100
#                                                   ...
# Intro to Indie Poptimism                            17
# Intro to Post-Teen Pop                              16
# post-teen pop                                       16
# ELETRIC POP & DANCE                                  9
# Post-Teen Pop                                        1
# Name: count, Length: 73, dtype: int64

# %%
pop_data.track_artist.value_counts()
# Out:
# track_artist
# The Chainsmokers    46
# David Guetta        44
# Javiera Mena        43
# Calvin Harris       42
# Kygo                41
#                     ..
# Kito                 1
# Rat City             1
# James Quick          1
# REYNA                1
# Sky Ferreira         1
# Name: count, Length: 2488, dtype: int64

# %%
pop_data.track_popularity.value_counts()
# Out:
# track_popularity
# 0      313
# 70     102
# 61     102
# 76     101
# 55      97
#       ...
# 97       6
# 95       5
# 92       4
# 96       2
# 100      1
# Name: count, Length: 100, dtype: int64

# %%
pop_data_feature=pop_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'danceability',
                                       'energy',
                                       'valence',
                                       ], 
                                        axis=1)

pop_data_feature.head()
# Out:
#   genre playlist_name      track_artist  \
# 0   pop     Pop Remix        Ed Sheeran
# 1   pop     Pop Remix          Maroon 5
# 2   pop     Pop Remix      Zara Larsson
# 3   pop     Pop Remix  The Chainsmokers
# 4   pop     Pop Remix     Lewis Capaldi
#
#                                           track_name  danceability  energy  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...         0.748   0.916
# 1                    Memories - Dillon Francis Remix         0.726   0.815
# 2                    All the Time - Don Diablo Remix         0.675   0.931
# 3                  Call You Mine - Keanu Silva Remix         0.718   0.930
# 4            Someone You Loved - Future Humans Remix         0.650   0.833
#
#    valence
# 0    0.518
# 1    0.693
# 2    0.613
# 3    0.277
# 4    0.725

# %%
pop_data_feature.to_csv("../data/pop/pop_data_feature.csv", index=False)

# %%
# visualise the data
sns.pairplot(pop_data_feature);

# %% [markdown]
# ### 3.1.1 Data of Indie Poptimism in Pop

# %%
# filtering the data based on genre pop


pop_Indie_Poptimism_data = pop_data[pop_data.playlist_name == "Indie Poptimism"]

# %%
pop_Indie_Poptimism_data.head()
# Out:
#      genre    playlist_name       track_artist       track_name  \
# 4444   pop  Indie Poptimism         Bea Miller        like that
# 4445   pop  Indie Poptimism  Anna of the North   Thank Me Later
# 4446   pop  Indie Poptimism         Alexx Mack         Your Car
# 4447   pop  Indie Poptimism             Coasts           Oceans
# 4448   pop  Indie Poptimism        Matt Maeson  Hallucinogenics
#
#       track_popularity  danceability  energy  key  loudness  mode  \
# 4444                73         0.573   0.441    6    -5.799     0
# 4445                54         0.755   0.496    2    -7.412     1
# 4446                17         0.559   0.642    9    -9.127     1
# 4447                42         0.520   0.845    9    -4.567     1
# 4448                66         0.549   0.653    0    -7.470     1
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 4444       0.0758       0.18600          0.000000    0.6100    0.389   61.657
# ...

# %%
# save the data

pop_Indie_Poptimism_data.to_csv("../data/pop/pop_Indie_Poptimism_data.csv", index=False)

# %% [markdown]
# ### 3.1.2 Data of Pop Remix in Pop

# %%
# filtering the data based on genre pop


pop_pop_remix_data = pop_data[songs_data_reindex.playlist_name == "Pop Remix"]
# Out:
# /var/folders/ks/vs48b2491ndfw81r2vkjvmd40000gn/T/ipykernel_49621/394242789.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pop_pop_remix_data = pop_data[songs_data_reindex.playlist_name == "Pop Remix"]

# %%
pop_pop_remix_data.head()
# Out:
#   genre playlist_name      track_artist  \
# 0   pop     Pop Remix        Ed Sheeran
# 1   pop     Pop Remix          Maroon 5
# 2   pop     Pop Remix      Zara Larsson
# 3   pop     Pop Remix  The Chainsmokers
# 4   pop     Pop Remix     Lewis Capaldi
#
#                                           track_name  track_popularity  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...                66
# 1                    Memories - Dillon Francis Remix                67
# 2                    All the Time - Don Diablo Remix                70
# 3                  Call You Mine - Keanu Silva Remix                60
# 4            Someone You Loved - Future Humans Remix                69
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# ...

# %%
# save the data

pop_pop_remix_data.to_csv("../data/pop/pop_pop_remix_data.csv", index=False)

# %%
pop_pop_remix_data.shape
# Out:
# (70, 17)

# %%
pop_pop_remix_data.track_artist.count
# Out:
# <bound method Series.count of 0           Ed Sheeran
# 1             Maroon 5
# 2         Zara Larsson
# 3     The Chainsmokers
# 4        Lewis Capaldi
#             ...
# 65              Khalid
# 66         Herve Pagez
# 67         Mark Ronson
# 68        James Arthur
# 69             Arlissa
# Name: track_artist, Length: 70, dtype: object>

# %%
pop_pop_remix_data.track_artist.value_counts()
# Out:
# track_artist
# Ed Sheeran            4
# The Chainsmokers      3
# Avicii                3
# Ava Max               3
# David Guetta          3
# AJ Mitchell           2
# Charli XCX            2
# Bazzi vs.             2
# James Arthur          2
# Starley               2
# Marshmello            2
# R3HAB                 2
# Steve Aoki            2
# Ellie Goulding        2
# Zara Larsson          2
# Lewis Capaldi         2
# Kaskade               1
# Olympis               1
# for KING & COUNTRY    1
# Lil Nas X             1
# Calvin Harris         1
# Why Don't We          1
# Mark Ronson           1
# SHAED                 1
# Herve Pagez           1
# DJ Snake              1
# Smash Mouth           1
# Khalid                1
# GASHI                 1
# Estelle               1
# Bastille              1
# ILLENIUM              1
# Sean Paul             1
# Sia                   1
# Billie Eilish         1
# Armin van Buuren      1
# Kygo                  1
# ...

# %%
# visualise the data
#sns.pairplot(pop_pop_remix_data);

# %%
sns.boxplot(x=pop_pop_remix_data.danceability);

# we may consider filtering based on danceability

# %%
sns.boxplot(x=pop_pop_remix_data.energy);

# we may consider filtering based on energy

# %%
pop_pop_remix_Ed_Sheeran_data = pop_pop_remix_data[pop_pop_remix_data.track_artist == "Ed Sheeran"]

# %%
# save the data

pop_pop_remix_Ed_Sheeran_data.to_csv("../data/pop/pop_pop_remix_Ed_Sheeran_data.csv", index=False)

# %%
pop_pop_remix_Ed_Sheeran_data.head()
# Out:
#    genre playlist_name track_artist  \
# 0    pop     Pop Remix   Ed Sheeran
# 5    pop     Pop Remix   Ed Sheeran
# 10   pop     Pop Remix   Ed Sheeran
# 15   pop     Pop Remix   Ed Sheeran
#
#                                            track_name  track_popularity  \
# 0   I Don't Care (with Justin Bieber) - Loud Luxur...                66
# 5   Beautiful People (feat. Khalid) - Jack Wins Remix                67
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...                58
# 15  South of the Border (feat. Camila Cabello & Ca...                66
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.748   0.916    6    -2.634     1       0.0583        0.1020
# 5          0.675   0.919    8    -5.385     1       0.1270        0.0799
# 10         0.679   0.923    6    -6.500     1       0.1810        0.1460
# 15         0.805   0.835    0    -4.603     1       0.0896        0.1300
#
# ...

# %%
#sns.pairplot(pop_pop_remix_Ed_Sheeran_data)

# %% [markdown]
# ### 3.1.3 Data of dance_pop in Pop

# %%
# filtering the data based on genre pop


pop_dance_pop_data = pop_data[songs_data_reindex.playlist_name == "Dance Pop"]
# Out:
# /var/folders/ks/vs48b2491ndfw81r2vkjvmd40000gn/T/ipykernel_49621/3378750834.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pop_dance_pop_data = pop_data[songs_data_reindex.playlist_name == "Dance Pop"]

# %%
pop_dance_pop_data.head()
# Out:
#    genre playlist_name         track_artist                track_name  \
# 70   pop     Dance Pop     The Chainsmokers             Call You Mine
# 71   pop     Dance Pop            Sam Feldt  Post Malone (feat. RANI)
# 72   pop     Dance Pop           Marshmello              Here With Me
# 73   pop     Dance Pop  5 Seconds of Summer       Easier - Seeb Remix
# 74   pop     Dance Pop       Ellie Goulding                   Sixteen
#
#     track_popularity  danceability  energy  key  loudness  mode  speechiness  \
# 70                39         0.591   0.702    7    -5.590     1       0.0289
# 71                83         0.590   0.642    7    -3.870     1       0.1220
# 72                83         0.791   0.565    5    -3.933     0       0.0439
# 73                71         0.564   0.747    5    -3.374     1       0.0584
# 74                81         0.669   0.801    8    -5.445     1       0.1360
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# ...

# %%
# visualise the data
#sns.pairplot(pop_dance_pop_data);

# %%
# save the data

pop_dance_pop_data.to_csv("../data/pop/pop_dance_pop_data.csv", index=False)

# %%
pop_dance_pop_data.shape
# Out:
# (138, 17)

# %%
pop_dance_pop_data.track_artist.count
# Out:
# <bound method Series.count of 70        The Chainsmokers
# 71               Sam Feldt
# 72              Marshmello
# 73     5 Seconds of Summer
# 74          Ellie Goulding
#               ...
# 535                 Avicii
# 536                 Tiësto
# 537          Martin Garrix
# 538                 Avicii
# 539     Axwell /\ Ingrosso
# Name: track_artist, Length: 138, dtype: object>

# %%
pop_dance_pop_data.track_artist.value_counts()
# Out:
# track_artist
# The Chainsmokers    8
# Calvin Harris       7
# Martin Garrix       6
# Avicii              6
# Armin van Buuren    6
#                    ..
# Lost Kings          1
# Elderbrook          1
# FANNYPACK           1
# Joel Corry          1
# Tim Berg            1
# Name: count, Length: 73, dtype: int64

# %%
pop_dance_pop_The_Chainsmokers_data = pop_dance_pop_data[pop_dance_pop_data.track_artist == "The Chainsmokers"]

# %%
# save the data

pop_dance_pop_The_Chainsmokers_data.to_csv("../data/pop/pop_dance_pop_The_Chainsmokers_data.csv", index=False)

# %%
pop_dance_pop_The_Chainsmokers_data.head()
# Out:
#     genre playlist_name      track_artist                      track_name  \
# 70    pop     Dance Pop  The Chainsmokers                   Call You Mine
# 79    pop     Dance Pop  The Chainsmokers  Takeaway (feat. Lennon Stella)
# 133   pop     Dance Pop  The Chainsmokers           Closer (feat. Halsey)
# 144   pop     Dance Pop  The Chainsmokers        Something Just Like This
# 150   pop     Dance Pop  The Chainsmokers                           Roses
#
#      track_popularity  danceability  energy  key  loudness  mode  speechiness  \
# 70                 39         0.591   0.702    7    -5.590     1       0.0289
# 79                 67         0.294   0.505    3    -8.106     1       0.0420
# 133                85         0.748   0.524    8    -5.599     1       0.0338
# 144                83         0.617   0.635   11    -6.769     0       0.0317
# 150                73         0.713   0.802    4    -7.055     1       0.0561
#
# ...

# %%
pop_dance_pop_The_Chainsmokers_data.shape
# Out:
# (8, 17)

# %%
# visualise the data
#sns.pairplot(pop_dance_pop_The_Chainsmokers_data);

# %% [markdown]
# ## 3.2 Data of edm

# %%
edm_data=songs_data_reindex[songs_data_reindex.genre == "edm"]

# %%
# save the data

edm_data.to_csv("../data/edm/edm_data.csv", index=False)

# %%
edm_data.head()
# Out:
#       genre       playlist_name     track_artist  \
# 26790   edm  Electro House 2020          Naeleck
# 26791   edm  Electro House 2020  Le Castle Vania
# 26792   edm  Electro House 2020           Tiësto
# 26793   edm  Electro House 2020          Naeleck
# 26794   edm  Electro House 2020       Fukkk Offf
#
#                                  track_name  track_popularity  danceability  \
# 26790  Disease - KATFYR "Tokyo Bound" Remix                43         0.677
# 26791                         Infinite Ammo                46         0.597
# 26792                                   WOW                10         0.601
# 26793           Threnody - Bombs Away Remix                50         0.836
# 26794                          Loudness War                33         0.843
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 26790   0.926    0    -3.307     1       0.0456      0.002980
# 26791   0.960    7    -1.940     0       0.0627      0.000094
# ...

# %%
edm_data.shape
# Out:
# (6043, 17)

# %%
edm_data.playlist_name.value_counts()
# Out:
# playlist_name
# Fitness Workout Electro | House | Dance | Progressive House    195
# EDM 2020 House & Dance                                         109
# Hands Up‏‏​​   ‍                                               100
# House Electro 2019                                             100
# Electro/Progressive/Club House                                 100
#                                                               ...
# Locker Room                                                     20
# EDM Pop                                                         11
# Big White Room-Jessie-J                                          7
# TOP 50 GLOBAL 2020 UPDATED WEEKLY 🌍🎶 WORLDWIDE                   3
# ALPAS Music Festival                                             3
# Name: count, Length: 78, dtype: int64

# %%
edm_data.track_artist.value_counts()
# Out:
# track_artist
# Martin Garrix                125
# Dimitri Vegas & Like Mike     79
# Hardwell                      76
# David Guetta                  60
# The Chainsmokers              49
#                             ...
# Paul van Dyk                   1
# KENO                           1
# Die Atzen                      1
# Jonth                          1
# Mat Zo                         1
# Name: count, Length: 2516, dtype: int64

# %%
edm_data_feature=edm_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'danceability',
                                       'energy',
                                       'loudness',
                                       'tempo',
                                       ], 
                                        axis=1)

edm_data_feature.head()
# Out:
#       genre       playlist_name     track_artist  \
# 26790   edm  Electro House 2020          Naeleck
# 26791   edm  Electro House 2020  Le Castle Vania
# 26792   edm  Electro House 2020           Tiësto
# 26793   edm  Electro House 2020          Naeleck
# 26794   edm  Electro House 2020       Fukkk Offf
#
#                                  track_name  danceability  energy  loudness  \
# 26790  Disease - KATFYR "Tokyo Bound" Remix         0.677   0.926    -3.307
# 26791                         Infinite Ammo         0.597   0.960    -1.940
# 26792                                   WOW         0.601   0.990    -3.016
# 26793           Threnody - Bombs Away Remix         0.836   0.926    -3.728
# 26794                          Loudness War         0.843   0.844    -4.779
#
#          tempo
# 26790  128.014
# 26791  127.016
# 26792  127.958
# 26793  127.977
# 26794  127.980

# %%
edm_data_feature.to_csv("../data/edm/edm_data_feature.csv", index=False)

# %%
# visualise the data
sns.pairplot(edm_data_feature);

# %% [markdown]
# ## 3.3 Data of rap

# %%
rap_data=songs_data_reindex[songs_data_reindex.genre == "rap"]

# %%
# save the data

rap_data.to_csv("../data/rap/rap_data.csv", index=False)

# %%
rap_data.head()
# Out:
#      genre playlist_name  track_artist                   track_name  \
# 5507   rap     RapCaviar        Future   Life Is Good (feat. Drake)
# 5508   rap     RapCaviar   Roddy Ricch                      The Box
# 5509   rap     RapCaviar    Mac Miller                    I Can See
# 5510   rap     RapCaviar  Lil Uzi Vert          Futsal Shuffle 2020
# 5511   rap     RapCaviar        Eminem  Godzilla (feat. Juice WRLD)
#
#       track_popularity  danceability  energy  key  loudness  mode  \
# 5507                93         0.676   0.609    2    -5.831     0
# 5508                98         0.896   0.586   10    -6.687     0
# 5509                73         0.699   0.503    5    -9.922     0
# 5510                91         0.881   0.457    7    -8.191     0
# 5511                79         0.808   0.745   10    -5.260     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
rap_data.shape
# Out:
# (5746, 17)

# %%
rap_data.playlist_name.value_counts()
# Out:
# playlist_name
# Southern Hip Hop            189
# Gangsta Rap/90's Hip-Hop    106
# Southern soul & hip hop     100
# Lush Lofi                   100
# Jazz Vibes                  100
#                            ...
# 3rd Coast Classics           37
# Viral Southern Hip Hop       36
# 90's Gangster Rap            35
# Gangsta Rap 💎 Rap Party      30
# Hip-Hop Mixtape              30
# Name: count, Length: 77, dtype: int64

# %%
rap_data.track_artist.value_counts()
# Out:
# track_artist
# Logic                              65
# 2Pac                               55
# 50 Cent                            53
# The Game                           46
# The Notorious B.I.G.               46
#                                    ..
# Vintage Trouble                     1
# Dan Auerbach                        1
# U2                                  1
# Tom Petty and the Heartbreakers     1
# Kap G                               1
# Name: count, Length: 2196, dtype: int64

# %%
rap_data_feature=rap_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'speechiness',
                                       'loudness',
                                       ], 
                                        axis=1)

rap_data_feature.head()
# Out:
#      genre playlist_name  track_artist                   track_name  \
# 5507   rap     RapCaviar        Future   Life Is Good (feat. Drake)
# 5508   rap     RapCaviar   Roddy Ricch                      The Box
# 5509   rap     RapCaviar    Mac Miller                    I Can See
# 5510   rap     RapCaviar  Lil Uzi Vert          Futsal Shuffle 2020
# 5511   rap     RapCaviar        Eminem  Godzilla (feat. Juice WRLD)
#
#       speechiness  loudness
# 5507       0.4810    -5.831
# 5508       0.0559    -6.687
# 5509       0.0882    -9.922
# 5510       0.1560    -8.191
# 5511       0.3420    -5.260

# %%
rap_data_feature.to_csv("../data/rap/rap_data_feature.csv", index=False)

# %%
# visualise the data
sns.pairplot(rap_data_feature);

# %% [markdown]
# ## 3.4 Data of r&b

# %%
rb_data=songs_data_reindex[songs_data_reindex.genre == "r&b"]

# %%
# save the data

rb_data.to_csv("../data/r&b/rb_data.csv", index=False)

# %%
rb_data.head()
# Out:
#       genre        playlist_name    track_artist  \
# 21359   r&b  New Hip Hop‏‏​​   ‍          Future
# 21360   r&b  New Hip Hop‏‏​​   ‍            Tyga
# 21361   r&b  New Hip Hop‏‏​​   ‍    Travis Scott
# 21362   r&b  New Hip Hop‏‏​​   ‍  Arizona Zervas
# 21363   r&b  New Hip Hop‏‏​​   ‍        JACKBOYS
#
#                                               track_name  track_popularity  \
# 21359                         Life Is Good (feat. Drake)                93
# 21360                                       Ayy Macarena                91
# 21361  HIGHEST IN THE ROOM (feat. ROSALÍA & Lil Baby)...                89
# 21362                                                FML                82
# 21363                        OUT WEST (feat. Young Thug)                87
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 21359         0.676   0.609    2    -5.831     0       0.4810        0.0706
# ...

# %%
rb_data.shape
# Out:
# (5431, 17)

# %%
rb_data.playlist_name.value_counts()
# Out:
# playlist_name
# Urban Contemporary                                170
# New Jack Swing                                    136
# Urban contemporary                                121
# New Hip Hop‏‏​​   ‍                               100
# Urban/Trap - Contemporary RAP                     100
#                                                  ...
# Best of New Jack Swing                             13
# Nidza Bleja - English HIP HOP/POP Songs            13
# URBAN NATION                                        9
# CSR 103:9 (GTA: SA)                                 7
# TOP 50 GLOBAL 2020 UPDATED WEEKLY 🌍🎶 WORLDWIDE      3
# Name: count, Length: 76, dtype: int64

# %%
rb_data.track_artist.value_counts()
# Out:
# track_artist
# Bobby Brown        42
# The Weeknd         41
# Janet Jackson      39
# Frank Ocean        36
# Drake              33
#                    ..
# Quinn O’Donnell     1
# HONÜ                1
# Chris Odd           1
# Astrojaxx           1
# Wendy Rene          1
# Name: count, Length: 2171, dtype: int64

# %%
rb_data_feature=rb_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'key',
                                       'valence',
                                       ], 
                                        axis=1)

rb_data_feature.head()
# Out:
#       genre        playlist_name    track_artist  \
# 21359   r&b  New Hip Hop‏‏​​   ‍          Future
# 21360   r&b  New Hip Hop‏‏​​   ‍            Tyga
# 21361   r&b  New Hip Hop‏‏​​   ‍    Travis Scott
# 21362   r&b  New Hip Hop‏‏​​   ‍  Arizona Zervas
# 21363   r&b  New Hip Hop‏‏​​   ‍        JACKBOYS
#
#                                               track_name  key  valence
# 21359                         Life Is Good (feat. Drake)    2    0.508
# 21360                                       Ayy Macarena    2    0.715
# 21361  HIGHEST IN THE ROOM (feat. ROSALÍA & Lil Baby)...    2    0.114
# 21362                                                FML    5    0.616
# 21363                        OUT WEST (feat. Young Thug)    8    0.309

# %%
rb_data_feature.to_csv("../data/r&b/rb_data_feature.csv", index=False)

# %%
# visualise the data
sns.pairplot(rb_data_feature);

# %% [markdown]
# ## 3.5 Data of latin

# %%
latin_data=songs_data_reindex[songs_data_reindex.genre == "latin"]

# %%
# save the data

latin_data.to_csv("../data/latin/latin_data.csv", index=False)

# %%
latin_data.head()
# Out:
#        genre   playlist_name      track_artist  \
# 16204  latin  Tropical House         Sam Feldt
# 16205  latin  Tropical House  Lost Frequencies
# 16206  latin  Tropical House          CAZZETTE
# 16207  latin  Tropical House         Klingande
# 16208  latin  Tropical House       Felix Jaehn
#
#                             track_name  track_popularity  danceability  \
# 16204                       Silverskin                 8         0.749
# 16205                        Recognise                60         0.717
# 16206  Handful Of Gold - Hounded Remix                50         0.735
# 16207                          Messiah                44         0.610
# 16208                      Never Alone                67         0.675
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 16204   0.520   10    -8.604     1       0.0456        0.2240
# 16205   0.741   10    -6.645     0       0.0530        0.1550
# ...

# %%
latin_data.shape
# Out:
# (5155, 17)

# %%
latin_data.playlist_name.value_counts()
# Out:
# playlist_name
# 2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥    194
# Tropical Vibes                                    117
# Tropical House                                    100
# Vibra Tropical                                    100
# Paraiso Tropical                                  100
#                                                  ...
# Tropical Nights                                    17
# Flow Selecto                                       16
# ¡Viva Latino!                                      16
# LATIN POP- DJ GIAN                                 12
# RADIO POP CHARTS                                    9
# Name: count, Length: 78, dtype: int64

# %%
latin_data.track_artist.value_counts()
# Out:
# track_artist
# Don Omar          100
# Daddy Yankee       61
# Wisin & Yandel     60
# J Balvin           56
# Ozuna              47
#                  ...
# Timna Momentus      1
# Molife              1
# Michel Gaross       1
# Sugar Blizz         1
# Los Rabanes         1
# Name: count, Length: 2229, dtype: int64

# %%
latin_data_feature=latin_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'danceability',
                                       'valence',
                                       'energy',
                                       'loudness',
                                       ], 
                                        axis=1)

latin_data_feature.head()
# Out:
#        genre   playlist_name      track_artist  \
# 16204  latin  Tropical House         Sam Feldt
# 16205  latin  Tropical House  Lost Frequencies
# 16206  latin  Tropical House          CAZZETTE
# 16207  latin  Tropical House         Klingande
# 16208  latin  Tropical House       Felix Jaehn
#
#                             track_name  danceability  valence  energy  \
# 16204                       Silverskin         0.749    0.759   0.520
# 16205                        Recognise         0.717    0.188   0.741
# 16206  Handful Of Gold - Hounded Remix         0.735    0.130   0.585
# 16207                          Messiah         0.610    0.624   0.748
# 16208                      Never Alone         0.675    0.446   0.827
#
#        loudness
# 16204    -8.604
# 16205    -6.645
# 16206    -9.673
# 16207    -6.856
# 16208    -4.793

# %%
latin_data_feature.to_csv("../data/latin/latin_data_feature.csv", index=False)

# %%
# visualise the data
sns.pairplot(latin_data_feature);

# %% [markdown]
# ## 3.6 Data of rock

# %%
rock_data=songs_data_reindex[songs_data_reindex.genre == "rock"]

# %%
# save the data

rock_data.to_csv("../data/rock/rock_data.csv", index=False)

# %%
rock_data.head()
# Out:
#       genre          playlist_name   track_artist             track_name  \
# 11253  rock  This Is Guns N' Roses  Guns N' Roses          Paradise City
# 11254  rock  This Is Guns N' Roses  Guns N' Roses    Shadow Of Your Love
# 11255  rock  This Is Guns N' Roses  Guns N' Roses  Welcome To The Jungle
# 11256  rock  This Is Guns N' Roses  Guns N' Roses           It's So Easy
# 11257  rock  This Is Guns N' Roses  Guns N' Roses              Nightrain
#
#        track_popularity  danceability  energy  key  loudness  mode  \
# 11253                78         0.273   0.952   11    -8.762     1
# 11254                58         0.416   0.995   10    -5.376     0
# 11255                78         0.446   0.954    8    -8.069     1
# 11256                60         0.375   0.973    8   -10.098     1
# 11257                61         0.400   0.992    6    -6.995     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
rock_data.shape
# Out:
# (4951, 17)

# %%
rock_data.playlist_name.value_counts()
# Out:
# playlist_name
# Permanent Wave                                                                            244
# Hard Rock Workout                                                                         219
# Classic Rock 70s 80s 90s, Rock Classics - 70s Rock, 80s Rock, 90s Rock Rock  Classicos    182
# permanent wave                                                                            139
# City Pop 1985 シティーポップ                                                                     100
#                                                                                          ...
# Classic Rock Workout                                                                       14
# Mega Rock Ballads: The Best Slow Rock Compilation Ever !                                   14
# Michael Learns To Rock album                                                               13
# Coldplay – Ghost Stories (Deluxe Edition)                                                  12
# ...

# %%
rock_data.track_artist.value_counts()
# Out:
# track_artist
# Queen                       134
# Guns N' Roses                76
# The Cranberries              45
# Scorpions                    44
# Van Halen                    42
#                            ...
# Trouble                       1
# Nine Inch Nails               1
# Unknown Mortal Orchestra      1
# Big Star                      1
# Tori Amos                     1
# Name: count, Length: 1573, dtype: int64

# %%
rock_data_feature=rock_data.reindex(['genre', 
                                       'playlist_name',
                                       'track_artist',
                                       'track_name',
                                       'liveness',
                                       'energy',
                                       'loudness',
                                       ], 
                                        axis=1)

rock_data_feature.head()
# Out:
#       genre          playlist_name   track_artist             track_name  \
# 11253  rock  This Is Guns N' Roses  Guns N' Roses          Paradise City
# 11254  rock  This Is Guns N' Roses  Guns N' Roses    Shadow Of Your Love
# 11255  rock  This Is Guns N' Roses  Guns N' Roses  Welcome To The Jungle
# 11256  rock  This Is Guns N' Roses  Guns N' Roses           It's So Easy
# 11257  rock  This Is Guns N' Roses  Guns N' Roses              Nightrain
#
#        liveness  energy  loudness
# 11253    0.1420   0.952    -8.762
# 11254    0.3400   0.995    -5.376
# 11255    0.2970   0.954    -8.069
# 11256    0.0947   0.973   -10.098
# 11257    0.1790   0.992    -6.995

# %%
rock_data_feature.to_csv("../data/rock/rock_data_feature.csv", index=False)

# %%
# visualise the data
sns.pairplot(rock_data_feature);

# %% [markdown]
# # 4.0 Data based on track popularity

# %%
# filtering the data based on track_popularity


popularity_top_data = songs_data_reindex[songs_data_reindex.track_popularity==100]

# %%
popularity_top_data.shape
# Out:
# (2, 17)

# %%
popularity_top_data.head()
# Out:
#        genre                                      playlist_name track_artist  \
# 1551     pop  post-teen alternative, indie, pop (large variety)  Tones and I
# 20091  latin                          Global Top 50 | 2020 Hits  Tones and I
#
#          track_name  track_popularity  danceability  energy  key  loudness  \
# 1551   Dance Monkey               100         0.824   0.588    6      -6.4
# 20091  Dance Monkey               100         0.824   0.588    6      -6.4
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 1551      0       0.0924         0.692          0.000104     0.149    0.513
# 20091     0       0.0924         0.692          0.000104     0.149    0.513
#
#         tempo  duration_ms
# 1551   98.027       209438
# 20091  98.027       209438

# %%
# filtering the data based on track_popularity


popularity_80plus_data = songs_data_reindex[songs_data_reindex.track_popularity>=80]

# %%
# save the data
popularity_80plus_data.to_csv("../data/popularity/popularity_80plus_data.csv", index=False)

# %%
popularity_80plus_data.head()
# Out:
#    genre playlist_name    track_artist                    track_name  \
# 41   pop     Pop Remix            Kygo                   Higher Love
# 43   pop     Pop Remix   Billie Eilish  bad guy (with Justin Bieber)
# 71   pop     Dance Pop       Sam Feldt      Post Malone (feat. RANI)
# 72   pop     Dance Pop      Marshmello                  Here With Me
# 74   pop     Dance Pop  Ellie Goulding                       Sixteen
#
#     track_popularity  danceability  energy  key  loudness  mode  speechiness  \
# 41                87         0.693   0.678    8    -7.159     1       0.0324
# 43                83         0.670   0.453    0   -11.265     1       0.2950
# 71                83         0.590   0.642    7    -3.870     1       0.1220
# 72                83         0.791   0.565    5    -3.933     0       0.0439
# 74                81         0.669   0.801    8    -5.445     1       0.1360
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# ...

# %%
popularity_80plus_data.shape
# Out:
# (1512, 17)

# %%
#sns.pairplot(popularity_80plus_data)

# %%
popularity_80plus_data.genre.value_counts()
# Out:
# genre
# pop      416
# latin    395
# r&b      308
# rap      180
# edm      143
# rock      70
# Name: count, dtype: int64

# %%
popularity_80plus_data.playlist_name.value_counts()
# Out:
# playlist_name
# 2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥                                                        175
# Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs          95
# Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop                                                        64
# Hip pop                                                                                                38
# Urbano: Latino Vibes                                                                                   35
#                                                                                                      ...
# Classic Rock Retrogamer                                                                                 1
# Classic Rock Workout                                                                                    1
# Classic Rock                                                                                            1
# ...

# %%
popularity_80plus_data.track_artist.value_counts()
# Out:
# track_artist
# Ed Sheeran        38
# Billie Eilish     33
# Selena Gomez      28
# Post Malone       28
# Travis Scott      28
#                   ..
# Arctic Monkeys     1
# NF                 1
# Anitta             1
# Pedro Sampaio      1
# gnash              1
# Name: count, Length: 259, dtype: int64

# %%
popularity_80plus_data.track_name.value_counts()
# Out:
# track_name
# Señorita                                     13
# I Don't Care (with Justin Bieber)            12
# Happy Now                                    12
# Closer (feat. Halsey)                        10
# Lose You To Love Me                          10
#                                              ..
# Under Pressure - Remastered                   1
# The Scientist                                 1
# Ritual                                        1
# Let You Down                                  1
# i hate u, i love u (feat. olivia o'brien)     1
# Name: count, Length: 494, dtype: int64

# %% [markdown]
# ## 4.1 Data of the edm popularity more than 80

# %%
# filtering the data based on track_popularity


popularity_80plus_edm_data = popularity_80plus_data[popularity_80plus_data.genre=="edm"]

# %%
popularity_80plus_edm_data=popularity_80plus_edm_data.sort_values('track_popularity',ascending=False)

# %%
# save the data
popularity_80plus_edm_data.to_csv("../data/popularity/popularity_80plus_edm_data.csv", index=False)

# %%
popularity_80plus_edm_data.head()
# Out:
#       genre                                      playlist_name  \
# 30202   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30209   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30207   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30203   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30197   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
#
#          track_artist       track_name  track_popularity  danceability  \
# 30202  Arizona Zervas          ROXANNE                99         0.621
# 30209     Post Malone          Circles                98         0.695
# 30207        Maroon 5         Memories                98         0.764
# 30203      The Weeknd  Blinding Lights                98         0.513
# 30197     Roddy Ricch          The Box                98         0.896
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 30202   0.601    6    -5.616     0       0.1480       0.05220
# ...

# %%
#sns.pairplot(popularity_80plus_edm_data)

# %%
popularity_80plus_edm_data.shape
# Out:
# (143, 17)

# %%
popularity_80plus_edm_data.playlist_name.value_counts()
# Out:
# playlist_name
# Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs                               51
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 - 2017 - 2018 - 2019 - 2020 TOP HITS                                         22
# Verão 2020 | Pop | Funk | Sertanejo | EDM | Top Hits 2019 - As Mais Tocadas                                                 12
# EDM 2020 House & Dance                                                                                                       9
# 2015 songs                                                                                                                   9
# EDM House & Dance                                                                                                            8
# Dancefloor Beats                                                                                                             6
# ...

# %%
popularity_80plus_edm_data.track_artist.value_counts()
# Out:
# track_artist
# Martin Garrix       7
# Ed Sheeran          7
# MEDUZA              5
# The Chainsmokers    4
# Shawn Mendes        4
#                    ..
# Mac Miller          1
# Jonas Brothers      1
# Pedro Capó          1
# Halsey              1
# P!nk                1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# ### 4.1.1 Data of top playlist of edm with popularity more than 80
# #### (Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs)

# %%
popularity_80plus_edm_top_playlist_data= popularity_80plus_edm_data[popularity_80plus_edm_data.playlist_name=="Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs"]

# %%
# save the data
popularity_80plus_edm_top_playlist_data.to_csv("../data/popularity/popularity_80plus_edm_top_playlist_data.csv", index=False)

# %%
popularity_80plus_edm_top_playlist_data.head()
# Out:
#       genre                                      playlist_name  \
# 30202   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30209   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30207   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30203   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30197   edm  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
#
#          track_artist       track_name  track_popularity  danceability  \
# 30202  Arizona Zervas          ROXANNE                99         0.621
# 30209     Post Malone          Circles                98         0.695
# 30207        Maroon 5         Memories                98         0.764
# 30203      The Weeknd  Blinding Lights                98         0.513
# 30197     Roddy Ricch          The Box                98         0.896
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 30202   0.601    6    -5.616     0       0.1480       0.05220
# ...

# %%
sns.boxplot(x=popularity_80plus_edm_top_playlist_data.danceability)
# Out:
# <Axes: xlabel='danceability'>

# %%
#sns.pairplot(popularity_80plus_edm_top_playlist_data)

# %% [markdown]
# ## 4.2 Data of the r&b of popularity more than 80

# %%
# filtering the data based on r&b in track_popularity


popularity_80plus_rb_data = popularity_80plus_data[popularity_80plus_data.genre=="r&b"]

# %%
popularity_80plus_rb_data=popularity_80plus_rb_data.sort_values('track_popularity',ascending=False)

# %%
popularity_80plus_rb_data.head()
# Out:
#       genre                                      playlist_name  \
# 21468   r&b                                 Contemporary Urban
# 23104   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23103   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23109   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23107   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
#
#          track_artist track_name  track_popularity  danceability  energy  key  \
# 21468  Arizona Zervas    ROXANNE                99         0.621   0.601    6
# 23104  Arizona Zervas    ROXANNE                99         0.621   0.601    6
# 23103         KAROL G       Tusa                98         0.803   0.715    2
# 23109     Post Malone    Circles                98         0.695   0.762    0
# 23107        Maroon 5   Memories                98         0.764   0.320   11
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
# save the data
popularity_80plus_rb_data.to_csv("../data/popularity/popularity_80plus_rb_data.csv", index=False)

# %%
popularity_80plus_rb_data.shape
# Out:
# (308, 17)

# %%
popularity_80plus_rb_data.playlist_name.value_counts()
# Out:
# playlist_name
# Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs    44
# Hip pop                                                                                          38
# New Hip Hop‏‏​​   ‍                                                                              33
# 2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥                                                   33
# Most Popular 2020 TOP 50                                                                         25
# Pop Hits 2020                                                                                    18
# Chixtape 5 - Tory Lanez                                                                          13
# Hip Pop 2019                                                                                     12
# Contemporary Urban                                                                               10
# ...

# %%
popularity_80plus_rb_data.track_artist.value_counts()
# Out:
# track_artist
# Billie Eilish     14
# Post Malone       10
# Khalid             9
# Ed Sheeran         8
# Young Thug         8
#                   ..
# Avicii             1
# Calum Scott        1
# Internet Money     1
# Baby Keem          1
# Major Lazer        1
# Name: count, Length: 132, dtype: int64

# %%
popularity_80plus_rb_data.track_name.value_counts()
# Out:
# track_name
# Motivation                           3
# Loyal (feat. Drake)                  3
# Beautiful People (feat. Khalid)      3
# Before You Go                        3
# I Don't Care (with Justin Bieber)    3
#                                     ..
# Family                               1
# One Kiss (with Dua Lipa)             1
# All of Me                            1
# Going Bad (feat. Drake)              1
# Vulnerable                           1
# Name: count, Length: 228, dtype: int64

# %% [markdown]
# ### 4.2.1 Data of the top playlist of r&b with popularity more than 80

# %%
popularity_80plus_rb_top_playlist_data=popularity_80plus_rb_data[popularity_80plus_rb_data.playlist_name=="Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs"]

# %%
# save the data
popularity_80plus_rb_top_playlist_data.to_csv("../data/popularity/popularity_first1_rb_data.csv", index=False)

# %%
popularity_80plus_rb_top_playlist_data.head()
# Out:
#       genre                                      playlist_name  \
# 23104   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23103   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23109   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23107   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23100   r&b  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
#
#          track_artist track_name  track_popularity  danceability  energy  key  \
# 23104  Arizona Zervas    ROXANNE                99         0.621   0.601    6
# 23103         KAROL G       Tusa                98         0.803   0.715    2
# 23109     Post Malone    Circles                98         0.695   0.762    0
# 23107        Maroon 5   Memories                98         0.764   0.320   11
# 23100     Roddy Ricch    The Box                98         0.896   0.586   10
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
popularity_80plus_rb_top_playlist_data.shape
# Out:
# (44, 17)

# %%
popularity_80plus_rb_top_playlist_data.track_artist.value_counts()
# Out:
# track_artist
# Ed Sheeran             3
# Harry Styles           3
# Travis Scott           2
# Post Malone            2
# Juice WRLD             2
# Lewis Capaldi          2
# BROCKHAMPTON           1
# Dalex                  1
# YNW Melly              1
# Dimelo Flow            1
# Mustard                1
# Arizona Zervas         1
# Lil Uzi Vert           1
# Doja Cat               1
# Shawn Mendes           1
# Mac Miller             1
# The Chainsmokers       1
# Selena Gomez           1
# Khalid                 1
# Sam Smith              1
# Rauw Alejandro         1
# Tyga                   1
# KAROL G                1
# Don Toliver            1
# Bad Bunny              1
# The Weeknd             1
# Anuel AA               1
# Future                 1
# blackbear              1
# Camila Cabello         1
# Regard                 1
# The Black Eyed Peas    1
# Dua Lipa               1
# Roddy Ricch            1
# Maroon 5               1
# Ava Max                1
# ...

# %%
#sns.pairplot(popularity_80plus_rb_top_playlist_data)

# %% [markdown]
# ## 4.3 Data based on the rock of popularity more than 80

# %%
# filtering the data based on Rock in track_popularity

popularity_80plus_rock_data = popularity_80plus_data[popularity_80plus_data.genre=="rock"]

# %%
popularity_80plus_rock_data=popularity_80plus_rock_data.sort_values('track_popularity',ascending=False)

# %%
# save the data
popularity_80plus_rock_data.to_csv("../data/popularity/popularity_80plus_rock_data.csv", index=False)

# %%
popularity_80plus_rock_data.head()
# Out:
#       genre                        playlist_name   track_artist  \
# 13900  rock                       Permanent Wave  Billie Eilish
# 14382  rock                           ②⓪①⑨ mixed    Post Malone
# 11798  rock              House Of The Rising Sun    Tame Impala
# 14539  rock                       permanent wave    Tame Impala
# 12109  rock  The Queen - La Discografia Completa          Queen
#
#                                           track_name  track_popularity  \
# 13900                                        bad guy                95
# 14382  Sunflower - Spider-Man: Into the Spider-Verse                88
# 11798                     The Less I Know The Better                85
# 14539                     The Less I Know The Better                85
# 12109                   Bohemian Rhapsody - 2011 Mix                84
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...

# %%
popularity_80plus_rock_data.shape
# Out:
# (70, 17)

# %%
popularity_80plus_rock_data.playlist_name.value_counts()
# Out:
# playlist_name
# Permanent wave                                                                            9
# The Sound of Permanent Wave                                                               7
# ②⓪①⑨ mixed                                                                                6
# Rock Classics                                                                             5
# The Sound of Album Rock                                                                   4
# Permanent Wave                                                                            3
# Classic Rock Playlist.                                                                    3
# House Of The Rising Sun                                                                   3
# permanent wave                                                                            3
# The Queen - La Discografia Completa                                                       3
# ...

# %%
popularity_80plus_rock_data.track_artist.value_counts()
# Out:
# track_artist
# AC/DC                           8
# Red Hot Chili Peppers           5
# Queen                           5
# Linkin Park                     4
# Eagles                          4
# Guns N' Roses                   4
# Journey                         3
# Eurythmics                      2
# Gorillaz                        2
# Nirvana                         2
# The Cranberries                 2
# Lynyrd Skynyrd                  2
# System Of A Down                2
# Tears For Fears                 2
# a-ha                            2
# TOTO                            2
# Tame Impala                     2
# R.E.M.                          1
# Creedence Clearwater Revival    1
# John Mayer                      1
# Michael Jackson                 1
# Harry Styles                    1
# Billie Eilish                   1
# Elton John                      1
# Coldplay                        1
# Post Malone                     1
# Arctic Monkeys                  1
# ...

# %% [markdown]
# ### 4.3.1 Data of the top playlist of rock with popularity more than 80

# %%
popularity_80plus_rock_top_playlist_data=popularity_80plus_rock_data[popularity_80plus_rock_data.playlist_name=="Permanent wave"]

# %%
# save the data
popularity_80plus_rock_top_playlist_data.to_csv("../data/popularity/popularity_80plus_rock_top_playlist_data.csv", index=False)

# %%
popularity_80plus_rock_top_playlist_data.head()
# Out:
#       genre   playlist_name   track_artist                        track_name  \
# 13778  rock  Permanent wave    Linkin Park                        In the End
# 13795  rock  Permanent wave           TOTO                            Africa
# 13753  rock  Permanent wave       Bon Jovi                Livin' On A Prayer
# 13741  rock  Permanent wave  Guns N' Roses               Sweet Child O' Mine
# 13758  rock  Permanent wave         Eagles  Hotel California - 2013 Remaster
#
#        track_popularity  danceability  energy  key  loudness  mode  \
# 13778                83         0.556   0.864    3    -5.870     0
# 13795                83         0.671   0.373    9   -18.064     1
# 13753                83         0.532   0.887    0    -3.757     1
# 13741                82         0.454   0.910    6    -7.766     1
# 13758                82         0.579   0.508    2    -9.484     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# ## 4.4 Data of rap popularity more than 80

# %%
# filtering the data based on rap in track_popularity

popularity_80plus_rap_data = popularity_80plus_data[popularity_80plus_data.genre=="rap"]

# %%
popularity_80plus_rap_data=popularity_80plus_rap_data.sort_values('track_popularity',ascending=False)

# %%
# save the data
popularity_80plus_rap_data.to_csv("../data/popularity/popularity_80plus_rap_data.csv", index=False)

# %%
popularity_80plus_rap_data.head()
# Out:
#       genre                     playlist_name   track_artist track_name  \
# 11184   rap                    Trap Americana    Roddy Ricch    The Box
# 11113   rap                       Trap 2020 🔥        KAROL G       Tusa
# 9018    rap  GTA San Andreas Radio Los Santos    Roddy Ricch    The Box
# 5508    rap                         RapCaviar    Roddy Ricch    The Box
# 9141    rap           Gangsta Rap 💎 Rap Party  Trevor Daniel    Falling
#
#        track_popularity  danceability  energy  key  loudness  mode  \
# 11184                98         0.896   0.586   10    -6.687     0
# 11113                98         0.803   0.715    2    -3.280     1
# 9018                 98         0.896   0.586   10    -6.687     0
# 5508                 98         0.896   0.586   10    -6.687     0
# 9141                 97         0.784   0.430   10    -8.756     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
popularity_80plus_rap_data.shape
# Out:
# (180, 17)

# %%
popularity_80plus_rap_data.playlist_name.value_counts()
# Out:
# playlist_name
# RapCaviar                                                                                         29
# Trap Americana                                                                                    22
# Trap 2020 🔥                                                                                       19
# GTA San Andreas Radio Los Santos                                                                  15
# Hip-Hop Favourites                                                                                15
# Sad Trap                                                                                          15
# Hip Hop Controller                                                                                11
# GANGSTA RAP                                                                                        7
# RAP Gangsta                                                                                        5
# ...

# %%
popularity_80plus_rap_data.track_artist.value_counts()
# Out:
# track_artist
# Travis Scott     11
# Young Thug       10
# Roddy Ricch       9
# Lil Baby          8
# Juice WRLD        8
#                  ..
# Arcangel          1
# Jhay Cortez       1
# Manuel Turizo     1
# DJ Luian          1
# Samra             1
# Name: count, Length: 73, dtype: int64

# %% [markdown]
# ### 4.4.1 Data of the top playlist of rock with popularity more than 80

# %%
popularity_80plus_rap_top_playlist_data = popularity_80plus_rap_data[popularity_80plus_rap_data.playlist_name=="RapCaviar"]

# %%
popularity_80plus_rap_top_playlist_data.head()
# Out:
#      genre playlist_name track_artist  \
# 5508   rap     RapCaviar  Roddy Ricch
# 5507   rap     RapCaviar       Future
# 5514   rap     RapCaviar       DaBaby
# 5533   rap     RapCaviar  Don Toliver
# 5522   rap     RapCaviar   Juice WRLD
#
#                                     track_name  track_popularity  \
# 5508                                   The Box                98
# 5507                Life Is Good (feat. Drake)                93
# 5514                                       BOP                93
# 5533                                   No Idea                92
# 5522  Bandit (with YoungBoy Never Broke Again)                92
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5508         0.896   0.586   10    -6.687     0       0.0559        0.1040
# 5507         0.676   0.609    2    -5.831     0       0.4810        0.0706
# 5514         0.769   0.787   11    -3.909     1       0.3670        0.1890
# ...

# %%
popularity_80plus_rap_top_playlist_data.shape
# Out:
# (29, 17)

# %%
popularity_80plus_rap_top_playlist_data.track_artist.value_counts()
# Out:
# track_artist
# Roddy Ricch                   3
# DaBaby                        3
# Lil Baby                      2
# Trippie Redd                  2
# Young Thug                    2
# Don Toliver                   2
# Lil Uzi Vert                  1
# YNW Melly                     1
# Travis Scott                  1
# Juice WRLD                    1
# JACKBOYS                      1
# Future                        1
# Kanye West                    1
# YoungBoy Never Broke Again    1
# Baby Keem                     1
# Internet Money                1
# 21 Savage                     1
# Russ                          1
# Stunna 4 Vegas                1
# Flipp Dinero                  1
# NLE Choppa                    1
# Name: count, dtype: int64

# %% [markdown]
# ## 4.5 Data of latin of popularity more than 80

# %%
# filtering the data based on latin in track_popularity

popularity_80plus_latin_data = popularity_80plus_data[popularity_80plus_data.genre=="latin"]

# %%
popularity_80plus_latin_data=popularity_80plus_latin_data.sort_values('track_popularity',ascending=False)

# %%
# save the data
popularity_80plus_latin_data.to_csv("../data/popularity/popularity_80plus_latin_data.csv", index=False)

# %%
popularity_80plus_latin_data.head()
# Out:
#        genre                                   playlist_name    track_artist  \
# 20091  latin                       Global Top 50 | 2020 Hits     Tones and I
# 20092  latin                       Global Top 50 | 2020 Hits  Arizona Zervas
# 18308  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥        Maroon 5
# 19716  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥        Maroon 5
# 20252  latin                            Urbano: Latino Vibes         KAROL G
#
#          track_name  track_popularity  danceability  energy  key  loudness  \
# 20091  Dance Monkey               100         0.824   0.588    6    -6.400
# 20092       ROXANNE                99         0.621   0.601    6    -5.616
# 18308      Memories                98         0.764   0.320   11    -7.209
# 19716      Memories                98         0.764   0.320   11    -7.209
# 20252          Tusa                98         0.803   0.715    2    -3.280
#
# ...

# %%
popularity_80plus_latin_data.shape
# Out:
# (395, 17)

# %%
popularity_80plus_latin_data.playlist_name.value_counts()
# Out:
# playlist_name
# 2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥                                 142
# Urbano: Latino Vibes                                                            35
# LATIN POP 2020 🔥 Pop latino actual                                              34
# Baila Reggaeton                                                                 21
# Global Top 50 | 2020 Hits                                                       18
# Mansión Reggaetón                                                               17
# Latest Latin American Hits 2020                                                 12
# Global X                                                                        10
# Tusa - Karol G | China - Anuel AA | Estrenos Reggaeton y Música Urbana 2019      9
# School Dance 2019 (Squeaky Clean)                                                9
# Today's Hits 2000-Present                                                        8
# ...

# %%
popularity_80plus_latin_data.track_artist.value_counts()
# Out:
# track_artist
# Ed Sheeran        13
# Dalex             12
# J Balvin          10
# Anuel AA           9
# Daddy Yankee       9
#                   ..
# NF                 1
# Martin Garrix      1
# French Montana     1
# Anitta             1
# Zedd               1
# Name: count, Length: 134, dtype: int64

# %% [markdown]
# ### 4.5.1 Data of the top playlist of latin with popularity more than 80

# %%
popularity_80plus_latin_top_playlist_data = popularity_80plus_latin_data[popularity_80plus_latin_data.playlist_name=="2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥"]

# %%
popularity_80plus_latin_top_playlist_data.head()
# Out:
#        genre                                   playlist_name track_artist  \
# 18308  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥     Maroon 5
# 19716  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥     Maroon 5
# 19707  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥  Roddy Ricch
# 18330  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥  Post Malone
# 19715  latin  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥   The Weeknd
#
#             track_name  track_popularity  danceability  energy  key  loudness  \
# 18308         Memories                98         0.764   0.320   11    -7.209
# 19716         Memories                98         0.764   0.320   11    -7.209
# 19707          The Box                98         0.896   0.586   10    -6.687
# 18330          Circles                98         0.695   0.762    0    -3.497
# 19715  Blinding Lights                98         0.513   0.796    1    -4.075
#
# ...

# %%
popularity_80plus_latin_top_playlist_data.shape
# Out:
# (142, 17)

# %%
popularity_80plus_latin_top_playlist_data.track_artist.value_counts()
# Out:
# track_artist
# Khalid                 8
# Selena Gomez           6
# Post Malone            6
# Ed Sheeran             6
# Travis Scott           6
# Camila Cabello         4
# Kygo                   4
# Doja Cat               4
# Billie Eilish          4
# Halsey                 4
# Lil Nas X              4
# Lewis Capaldi          4
# Shawn Mendes           4
# Harry Styles           4
# Maroon 5               2
# Dominic Fike           2
# Young Thug             2
# Riton                  2
# Jonas Brothers         2
# Alan Walker            2
# Chris Brown            2
# Marshmello             2
# Ariana Grande          2
# The Chainsmokers       2
# Mabel                  2
# Kina                   2
# Tyler, The Creator     2
# BTS                    2
# Normani                2
# Silk City              2
# Mac Miller             2
# JP Saxe                2
# MEDUZA                 2
# Drake                  2
# The Weeknd             2
# Dua Lipa               2
# ...

# %% [markdown]
# ## 4.6 Data of pop of populatiry more than 80

# %%
# filtering the data based on pop in track_popularity

popularity_80plus_pop_data = popularity_80plus_data[popularity_80plus_data.genre=="pop"]

# %%
popularity_80plus_pop_data=popularity_80plus_pop_data.sort_values('track_popularity',ascending=False)

# %%
# save the data
popularity_80plus_pop_data.to_csv("../data/popularity/popularity_80plus_pop_data.csv", index=False)

# %%
popularity_80plus_pop_data.head()
# Out:
#      genre                                      playlist_name track_artist  \
# 1551   pop  post-teen alternative, indie, pop (large variety)  Tones and I
# 687    pop                                        Todo Éxitos      KAROL G
# 4713   pop                                  indie poptimism🕺🏻   The Weeknd
# 1301   pop    Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop  Post Malone
# 716    pop                                        Todo Éxitos   The Weeknd
#
#            track_name  track_popularity  danceability  energy  key  loudness  \
# 1551     Dance Monkey               100         0.824   0.588    6    -6.400
# 687              Tusa                98         0.803   0.715    2    -3.280
# 4713  Blinding Lights                98         0.513   0.796    1    -4.075
# 1301          Circles                98         0.695   0.762    0    -3.497
# 716   Blinding Lights                98         0.513   0.796    1    -4.075
#
# ...

# %%
popularity_80plus_pop_data.shape
# Out:
# (416, 17)

# %%
popularity_80plus_pop_data.playlist_name.value_counts()
# Out:
# playlist_name
# Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop                                              64
# Todo Éxitos                                                                                  29
# indie poptimism🕺🏻                                                                            28
# Dance Pop                                                                                    24
# Post pop teen                                                                                21
# Electropop 2019                                                                              18
# post-teen alternative, indie, pop (large variety)                                            16
# Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s                                            15
# The Sound of Post-Teen Pop                                                                   14
# 10er Playlist                                                                                14
# ...

# %%
popularity_80plus_pop_data.track_artist.value_counts()
# Out:
# track_artist
# Avicii              11
# Billie Eilish       11
# The Weeknd          11
# The Chainsmokers    11
# Selena Gomez        11
#                     ..
# Lil Uzi Vert         1
# Dynoro               1
# Cardi B              1
# Dan + Shay           1
# Coolio               1
# Name: count, Length: 152, dtype: int64

# %% [markdown]
# ### 4.6.1 Data of the top playlist of latin with popularity more than 80

# %%
popularity_80plus_pop_top_playlist_data=popularity_80plus_pop_data[popularity_80plus_pop_data.playlist_name=="Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop"]

# %%
# save the data
popularity_80plus_pop_top_playlist_data.to_csv("../data/popularity/popularity_80plus_pop_top_playlist_data.csv", index=False)

# %%
popularity_80plus_pop_top_playlist_data.head()
# Out:
#      genre                                    playlist_name  \
# 1301   pop  Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1300   pop  Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1302   pop  Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1307   pop  Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1316   pop  Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
#
#              track_artist                 track_name  track_popularity  \
# 1301          Post Malone                    Circles                98
# 1300             Maroon 5                   Memories                98
# 1302             Dua Lipa            Don't Start Now                97
# 1307  The Black Eyed Peas  RITMO (Bad Boys For Life)                96
# 1316        Billie Eilish                    bad guy                95
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1301         0.695   0.762    0    -3.497     1       0.0395        0.1920
# ...

# %%
popularity_80plus_pop_top_playlist_data.shape
# Out:
# (64, 17)

# %% [markdown]
# # 5.0 Data of track Poison
# ## (The track name with most songs)

# %%
# filtering the data based on track_name Poison


track_name_Poison_data = songs_data_reindex[songs_data_reindex.track_name=="Poison"]

# %%
track_name_Poison_data=track_name_Poison_data.sort_values('track_popularity',ascending=False)

# %%
track_name_Poison_data.shape
# Out:
# (22, 17)

# %%
# save the data
track_name_Poison_data.to_csv("../data/track_name/track_name_Poison_data.csv", index=False)

# %%
track_name_Poison_data.head()
# Out:
#       genre            playlist_name    track_artist track_name  \
# 12250  rock  The Sound of Album Rock    Alice Cooper     Poison
# 12863  rock     Classic Rock Legends    Alice Cooper     Poison
# 15396  rock  Hard Rock Cafe Classics    Alice Cooper     Poison
# 21765   r&b       Urban Contemporary    Brent Faiyaz     Poison
# 24420   r&b            New Jack City  Bell Biv DeVoe     Poison
#
#        track_popularity  danceability  energy  key  loudness  mode  \
# 12250                70         0.280   0.908    2    -5.509     0
# 12863                70         0.280   0.908    2    -5.509     0
# 15396                70         0.280   0.908    2    -5.509     0
# 21765                68         0.689   0.394    2   -10.102     0
# 24420                66         0.840   0.560    6   -10.530     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 12250        0.109       0.03270          0.000009    0.1800    0.260
# ...

# %%
# save the data
track_name_Poison_data.to_csv("../data/track_name/track_name_Poison_data.csv", index=False)

# %%
sns.pairplot(track_name_Poison_data)

# %%
track_name_Poison_data.playlist_name.value_counts()
# Out:
# playlist_name
# Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs    2
# The Sound of Album Rock                                                                          1
# New Jack Swing - 90s R&B fused w Hip Hop                                                         1
# 90's NEW JACK SWING                                                                              1
# New Jack Swing                                                                                   1
# 90s R&B - The BET Planet Groove/Midnight Love Mix                                                1
# Jeff Seid Electro House                                                                          1
# CSR 103:9 (GTA: SA)                                                                              1
# Girl On Fire                                                                                     1
# ...

# %%
track_name_Poison_data.genre.value_counts()
# Out:
# genre
# r&b     10
# rock     7
# rap      2
# edm      2
# pop      1
# Name: count, dtype: int64

# %%
track_name_Poison_data.track_popularity.value_counts()
# Out:
# track_popularity
# 70    3
# 47    3
# 0     3
# 59    2
# 57    2
# 68    1
# 66    1
# 60    1
# 49    1
# 48    1
# 43    1
# 36    1
# 2     1
# 1     1
# Name: count, dtype: int64

# %% [markdown]
# # 6.0 Data of track artist Martin Garrix
# ## (The track artist with the most songs)

# %%
# filtering the data based on track artist Martin Garrix


track_artist_Martin_Garrix_data = songs_data_reindex[songs_data_reindex.track_artist=="Martin Garrix"]

# %%
# save the data
track_artist_Martin_Garrix_data.to_csv("../data/track_artist/track_artist_Martin_Garrix_data.csv", index=False)

# %%
track_artist_Martin_Garrix_data.shape
# Out:
# (161, 17)

# %%
track_artist_Martin_Garrix_data.head()
# Out:
#     genre playlist_name   track_artist  \
# 14    pop     Pop Remix  Martin Garrix
# 108   pop     Dance Pop  Martin Garrix
# 125   pop     Dance Pop  Martin Garrix
# 137   pop     Dance Pop  Martin Garrix
# 199   pop    Dance Room  Martin Garrix
#
#                                             track_name  track_popularity  \
# 14   Summer Days (feat. Macklemore & Patrick Stump ...                63
# 108                              No Sleep (feat. Bonn)                76
# 125                                  Home (feat. Bonn)                72
# 137                                Scared to Be Lonely                81
# 199                     Used To Love (with Dean Lewis)                83
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 14          0.690   0.780    5    -4.446     0       0.0594       0.00733
# 108         0.440   0.635   11    -6.385     1       0.0326       0.12900
# ...

# %%
sns.pairplot(track_artist_Martin_Garrix_data)

# %%
#the categories of genre
track_artist_Martin_Garrix_data.genre.value_counts()
# Out:
# genre
# edm      125
# pop       30
# latin      3
# rap        2
# r&b        1
# Name: count, dtype: int64

# %%
#the categories of playlist_name
track_artist_Martin_Garrix_data.playlist_name.value_counts()
# Out:
# playlist_name
# Jeff Seid Electro House                                                                               25
# Hands Up‏‏​​   ‍                                                                                      14
# Big Room House | Festival Bangers                                                                     13
# New House   ‍                                                                                          9
# Festival Music 2019 - Warm Up Music (EDM, Big Room & Progressive House)                                8
# Dance Pop                                                                                              6
# Crossfit‏‏​​   ‍                                                                                       6
# Fitness Workout Electro | House | Dance | Progressive House                                            5
# Pop Warmup 130 BPM                                                                                     4
# ...

# %%
#the categories of track_popularity
track_artist_Martin_Garrix_data.track_popularity.value_counts()
# Out:
# track_popularity
# 2     15
# 0      8
# 68     8
# 76     8
# 52     6
# 5      6
# 83     6
# 59     6
# 77     6
# 56     5
# 80     5
# 49     5
# 53     4
# 50     4
# 71     4
# 57     4
# 72     4
# 75     3
# 74     3
# 10     3
# 62     3
# 1      3
# 81     3
# 4      3
# 51     3
# 69     3
# 66     2
# 40     2
# 38     2
# 42     2
# 60     2
# 43     2
# 3      2
# 54     2
# 64     2
# 47     2
# 58     2
# 30     1
# 44     1
# 63     1
# 36     1
# 31     1
# 8      1
# 61     1
# 41     1
# Name: count, dtype: int64
